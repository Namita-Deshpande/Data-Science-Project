# %%
##Importing libraries

import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
import sklearn.linear_model
import pandas as pd 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest,f_classif
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
#Import the training and the test data into numpy or pandas.
#as the question stated that there are no headers
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.shape #Displays no. of rows and columns
# Out:
# (418, 12)

# %%
df
#Overall data gets displayed
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.info()
# Dataset whole info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull().sum() #checking column that contain nan
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.isnull() #checking column that contain nan
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
x=df.drop(['Name','Cabin'],axis=1) # removing name column.

# %%
x
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            892         0       3    male  34.5      0      0
# 1            893         1       3  female  47.0      1      0
# 2            894         0       2    male  62.0      0      0
# 3            895         0       3    male  27.0      0      0
# 4            896         1       3  female  22.0      1      1
# ..           ...       ...     ...     ...   ...    ...    ...
# 413         1305         0       3    male   NaN      0      0
# 414         1306         1       1  female  39.0      0      0
# 415         1307         0       3    male  38.5      0      0
# 416         1308         0       3    male   NaN      0      0
# 417         1309         0       3    male   NaN      1      1
#
#                  Ticket      Fare Embarked
# 0                330911    7.8292        Q
# 1                363272    7.0000        S
# 2                240276    9.6875        Q
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
x.replace(to_replace=['male'],value=0,inplace=True)

# %%
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0            892         0       3    0  34.5      0      0
# 1            893         1       3    1  47.0      1      0
# 2            894         0       2    0  62.0      0      0
# 3            895         0       3    0  27.0      0      0
# 4            896         1       3    1  22.0      1      1
# ..           ...       ...     ...  ...   ...    ...    ...
# 413         1305         0       3    0   NaN      0      0
# 414         1306         1       1    1  39.0      0      0
# 415         1307         0       3    0  38.5      0      0
# 416         1308         0       3    0   NaN      0      0
# 417         1309         0       3    0   NaN      1      1
#
#                  Ticket      Fare Embarked
# 0                330911    7.8292        Q
# 1                363272    7.0000        S
# 2                240276    9.6875        Q
# 3                315154    8.6625        S
# ...

# %%
x.replace(to_replace=['female'],value=1,inplace=True)

# %%
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0            892         0       3    0  34.5      0      0
# 1            893         1       3    1  47.0      1      0
# 2            894         0       2    0  62.0      0      0
# 3            895         0       3    0  27.0      0      0
# 4            896         1       3    1  22.0      1      1
# ..           ...       ...     ...  ...   ...    ...    ...
# 413         1305         0       3    0   NaN      0      0
# 414         1306         1       1    1  39.0      0      0
# 415         1307         0       3    0  38.5      0      0
# 416         1308         0       3    0   NaN      0      0
# 417         1309         0       3    0   NaN      1      1
#
#                  Ticket      Fare Embarked
# 0                330911    7.8292        Q
# 1                363272    7.0000        S
# 2                240276    9.6875        Q
# 3                315154    8.6625        S
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Sex          418 non-null    int64
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Embarked     418 non-null    object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 32.8+ KB

# %%
x["Ticket"]
# Out:
# 0                  330911
# 1                  363272
# 2                  240276
# 3                  315154
# 4                 3101298
#               ...
# 413             A.5. 3236
# 414              PC 17758
# 415    SOTON/O.Q. 3101262
# 416                359309
# 417                  2668
# Name: Ticket, Length: 418, dtype: object

# %% [markdown]
# # In case you have a letter or word in your data, you have to change the it to numbers using split and trim function.

# %%
#x["Ticket"] =x["Ticket"].str.split(" ", n=1, expand=False)

# %%
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  Ticket      Fare  \
# 0            892         0       3    0  34.5      0      0     NaN    7.8292
# 1            893         1       3    1  47.0      1      0     NaN    7.0000
# 2            894         0       2    0  62.0      0      0     NaN    9.6875
# 3            895         0       3    0  27.0      0      0     NaN    8.6625
# 4            896         1       3    1  22.0      1      1     NaN   12.2875
# ..           ...       ...     ...  ...   ...    ...    ...     ...       ...
# 413         1305         0       3    0   NaN      0      0     NaN    8.0500
# 414         1306         1       1    1  39.0      0      0     NaN  108.9000
# 415         1307         0       3    0  38.5      0      0     NaN    7.2500
# 416         1308         0       3    0   NaN      0      0     NaN    8.0500
# 417         1309         0       3    0   NaN      1      1     NaN   22.3583
#
#     Embarked
# 0          Q
# ...

# %%
x['Ticket'] = x['Ticket'].str.replace('\D', '', regex=True)

# %%
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch   Ticket  \
# 0            892         0       3    0  34.5      0      0   330911
# 1            893         1       3    1  47.0      1      0   363272
# 2            894         0       2    0  62.0      0      0   240276
# 3            895         0       3    0  27.0      0      0   315154
# 4            896         1       3    1  22.0      1      1  3101298
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 413         1305         0       3    0   NaN      0      0    53236
# 414         1306         1       1    1  39.0      0      0    17758
# 415         1307         0       3    0  38.5      0      0  3101262
# 416         1308         0       3    0   NaN      0      0   359309
# 417         1309         0       3    0   NaN      1      1     2668
#
#          Fare Embarked
# 0      7.8292        Q
# 1      7.0000        S
# 2      9.6875        Q
# 3      8.6625        S
# ...

# %% [markdown]
# #Method 1: Remove Specific Characters from Strings -
#
# df['my_column'] = df['my_column'].str.replace('this_string', '')

# %% [markdown]
# #Method 2: Remove All Letters from Strings
#
# df['my_column'] = df['my_column'].str.replace('\D', '', regex=True)

# %% [markdown]
# #Method 3: Remove All Numbers from Strings
#
# df['my_column'] = df['my_column'].str.replace('\d+', '', regex=True)

# %%
x.replace(to_replace=['S'],value=0,inplace=True)

# %%
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch   Ticket  \
# 0            892         0       3    0  34.5      0      0   330911
# 1            893         1       3    1  47.0      1      0   363272
# 2            894         0       2    0  62.0      0      0   240276
# 3            895         0       3    0  27.0      0      0   315154
# 4            896         1       3    1  22.0      1      1  3101298
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 413         1305         0       3    0   NaN      0      0    53236
# 414         1306         1       1    1  39.0      0      0    17758
# 415         1307         0       3    0  38.5      0      0  3101262
# 416         1308         0       3    0   NaN      0      0   359309
# 417         1309         0       3    0   NaN      1      1     2668
#
#          Fare Embarked
# 0      7.8292        Q
# 1      7.0000        0
# 2      9.6875        Q
# 3      8.6625        0
# ...

# %%
x.replace(to_replace=['Q'],value=1,inplace=True)

# %%
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch   Ticket  \
# 0            892         0       3    0  34.5      0      0   330911
# 1            893         1       3    1  47.0      1      0   363272
# 2            894         0       2    0  62.0      0      0   240276
# 3            895         0       3    0  27.0      0      0   315154
# 4            896         1       3    1  22.0      1      1  3101298
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 413         1305         0       3    0   NaN      0      0    53236
# 414         1306         1       1    1  39.0      0      0    17758
# 415         1307         0       3    0  38.5      0      0  3101262
# 416         1308         0       3    0   NaN      0      0   359309
# 417         1309         0       3    0   NaN      1      1     2668
#
#          Fare Embarked
# 0      7.8292        1
# 1      7.0000        0
# 2      9.6875        1
# 3      8.6625        0
# ...

# %%
x.replace(to_replace=['C'],value=2,inplace=True)

# %%
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch   Ticket  \
# 0            892         0       3    0  34.5      0      0   330911
# 1            893         1       3    1  47.0      1      0   363272
# 2            894         0       2    0  62.0      0      0   240276
# 3            895         0       3    0  27.0      0      0   315154
# 4            896         1       3    1  22.0      1      1  3101298
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 413         1305         0       3    0   NaN      0      0    53236
# 414         1306         1       1    1  39.0      0      0    17758
# 415         1307         0       3    0  38.5      0      0  3101262
# 416         1308         0       3    0   NaN      0      0   359309
# 417         1309         0       3    0   NaN      1      1     2668
#
#          Fare  Embarked
# 0      7.8292         1
# 1      7.0000         0
# 2      9.6875         1
# 3      8.6625         0
# ...

# %%
df.isnull().sum() #checking column that contain nan
                  # Because Prof.Grozea had put -12345 value in the dataframe so there is no Nan value hence 0
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
x.isnull().sum() #checking column that contain nan
                  # Because Prof.Grozea had put -12345 value in the dataframe so there is no Nan value hence 0
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
median=x.median()
median
# Out:
# PassengerId     1100.5
# Survived           0.0
# Pclass             3.0
# Sex                0.0
# Age               27.0
# SibSp              0.0
# Parch              0.0
# Ticket         53286.5
# Fare           14.4542
# Embarked           0.0
# dtype: object

# %%
x.fillna(x.median(),inplace=True)
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch   Ticket  \
# 0            892         0       3    0  34.5      0      0   330911
# 1            893         1       3    1  47.0      1      0   363272
# 2            894         0       2    0  62.0      0      0   240276
# 3            895         0       3    0  27.0      0      0   315154
# 4            896         1       3    1  22.0      1      1  3101298
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 413         1305         0       3    0  27.0      0      0    53236
# 414         1306         1       1    1  39.0      0      0    17758
# 415         1307         0       3    0  38.5      0      0  3101262
# 416         1308         0       3    0  27.0      0      0   359309
# 417         1309         0       3    0  27.0      1      1     2668
#
#          Fare  Embarked
# 0      7.8292         1
# 1      7.0000         0
# 2      9.6875         1
# 3      8.6625         0
# ...

# %%
x.isnull().sum() #checking column that contain nan
                  # Because Prof.Grozea had put -12345 value in the dataframe so there is no Nan value hence 0
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Sex          418 non-null    int64
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    float64
#  9   Embarked     418 non-null    int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 32.8+ KB

# %%
x['Ticket'].astype(object).astype(int) # raises ValueError
# Out:
# 0       330911
# 1       363272
# 2       240276
# 3       315154
# 4      3101298
#         ...
# 413      53236
# 414      17758
# 415    3101262
# 416     359309
# 417       2668
# Name: Ticket, Length: 418, dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Sex          418 non-null    int64
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    float64
#  9   Embarked     418 non-null    int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 32.8+ KB

# %%
x['Ticket'] = x['Ticket'].astype(float)

# %%
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Ticket  \
# 0            892         0       3    0  34.5      0      0   330911.0
# 1            893         1       3    1  47.0      1      0   363272.0
# 2            894         0       2    0  62.0      0      0   240276.0
# 3            895         0       3    0  27.0      0      0   315154.0
# 4            896         1       3    1  22.0      1      1  3101298.0
# ..           ...       ...     ...  ...   ...    ...    ...        ...
# 413         1305         0       3    0  27.0      0      0    53236.0
# 414         1306         1       1    1  39.0      0      0    17758.0
# 415         1307         0       3    0  38.5      0      0  3101262.0
# 416         1308         0       3    0  27.0      0      0   359309.0
# 417         1309         0       3    0  27.0      1      1     2668.0
#
#          Fare  Embarked
# 0      7.8292         1
# 1      7.0000         0
# 2      9.6875         1
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Sex          418 non-null    int64
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    float64
#  8   Fare         418 non-null    float64
#  9   Embarked     418 non-null    int64
# dtypes: float64(3), int64(7)
# memory usage: 32.8 KB

# %%
#removing outlier (noise in data)
import scipy.stats as stats
import numpy as np
z_scores = np.abs(stats.zscore(x))
threshold =3
print("size before removing outliers:",x.shape)
outliers_df = x[(z_scores > threshold).any(axis=1)]
x=x[(z_scores <= threshold).all(axis=1)]
print("size before removing outliers:",x.shape)
# Out:
# size before removing outliers: (418, 10)
# size before removing outliers: (383, 10)

# %%
y=x['Survived'] #extracting last column as target features(dependent feature)
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 383, dtype: int64

# %%
z=x.drop('Survived',axis=1) #extracting all column expect target column as independent feauture

z
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch     Ticket      Fare  \
# 0            892       3    0  34.5      0      0   330911.0    7.8292
# 1            893       3    1  47.0      1      0   363272.0    7.0000
# 2            894       2    0  62.0      0      0   240276.0    9.6875
# 3            895       3    0  27.0      0      0   315154.0    8.6625
# 4            896       3    1  22.0      1      1  3101298.0   12.2875
# ..           ...     ...  ...   ...    ...    ...        ...       ...
# 413         1305       3    0  27.0      0      0    53236.0    8.0500
# 414         1306       1    1  39.0      0      0    17758.0  108.9000
# 415         1307       3    0  38.5      0      0  3101262.0    7.2500
# 416         1308       3    0  27.0      0      0   359309.0    8.0500
# 417         1309       3    0  27.0      1      1     2668.0   22.3583
#
#      Embarked
# 0           1
# 1           0
# 2           1
# 3           0
# 4           0
# ..        ...
# ...

# %%
# Split our data between a training set and a test set:
z_train, z_test, y_train, y_test = train_test_split(z, y,test_size=0.30,
                                                    stratify=y, random_state=66)

# %%
z_train.shape,z_test.shape
# Out:
# ((268, 9), (115, 9))

# %%
y_train.shape,y_test.shape
# Out:
# ((268,), (115,))

# %%
correlation=x.corr()['Survived']
correlation
# Out:
# PassengerId   -0.007271
# Survived       1.000000
# Pclass        -0.071010
# Sex            1.000000
# Age           -0.043291
# SibSp          0.121077
# Parch          0.238008
# Ticket         0.022625
# Fare           0.140545
# Embarked       0.077108
# Name: Survived, dtype: float64

# %%
sorted_features=correlation.abs().sort_values(ascending=False)
sorted_features.head(10)
# Out:
# Survived       1.000000
# Sex            1.000000
# Parch          0.238008
# Fare           0.140545
# SibSp          0.121077
# Embarked       0.077108
# Pclass         0.071010
# Age            0.043291
# Ticket         0.022625
# PassengerId    0.007271
# Name: Survived, dtype: float64

# %%
#Random forest classifier
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier(n_estimators=100,random_state=100)

#fit model
forest.fit(z_train,y_train)

#prediction 
pred = forest.predict(z_test)

#predicted labels
pred[:10]

#Accuracy percentage
accuracy_percentage=100*np.sum(pred==y_test)/len(y_test)
accuracy_percentage
# Out:
# 100.0

# %%
auc=sklearn.metrics.roc_auc_score(y_test,pred)
print("auc",auc)
#AUC
# Out:
# auc 1.0

# %%
np.savetxt('TitanicSurvival.txt',pred)
